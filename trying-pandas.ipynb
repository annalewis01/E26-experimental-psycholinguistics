# %% [markdown]
# ## PANDAS

# %%
import pandas as pd

# %%
a = [3, 4, 78, 501]
b = [92, 108, 6, 4079]
c = [38, 203, 96, 335]

# %%
box = pd.DataFrame({"a": a, "b": b, "c": c})

# %%
type(box)
# Out:
# pandas.DataFrame

# %%
print(box)
# Out:
#      a     b    c
# 0    3    92   38
# 1    4   108  203
# 2   78     6   96
# 3  501  4079  335

# %%
box
# Out:
#      a     b    c
# 0    3    92   38
# 1    4   108  203
# 2   78     6   96
# 3  501  4079  335

# %%
# data frame and dictionary are very similar structurally. essentially just fed it a dictionary and it's turned it into a nice little dataframe box

# %%
dir(box)
# Out:
# ['T',
#  '_AXIS_LEN',
#  '_AXIS_ORDERS',
#  '_AXIS_TO_AXIS_NUMBER',
#  '_HANDLED_TYPES',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__annotations__',
#  '__array__',
#  '__array_priority__',
#  '__array_ufunc__',
#  '__arrow_c_stream__',
#  '__bool__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__dataframe__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__firstlineno__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
#  '__module__',
#  '__mul__',
#  '__ne__',
# ...

# %%
#now we want to get the data out again

box["a"]
# Out:
# 0      3
# 1      4
# 2     78
# 3    501
# Name: a, dtype: int64

# %%
d = box["a"]

# %%
type(d)
# Out:
# pandas.Series

# %%
e = list(d)

# %%
e
# Out:
# [3, 4, 78, 501]

# %%
a == e
# == means something is identical
# Out:
# True

# %%
box["row_mean"] = box.mean(axis=1)

# %%
box
# Out:
#      a     b    c     row_mean
# 0    3    92   38    44.333333
# 1    4   108  203   105.000000
# 2   78     6   96    60.000000
# 3  501  4079  335  1638.333333

# %%
df = pd.read_csv("/work/E26-experimental-psycholinguistics/Stroop-raw-over-the-years.csv")
# to import data from a csv file. 
# copy path, start with /work/

# %%
df
# Out:
#      Reading_NoInt  Naming_Int  Naming_NoInt  Reading_Int  Year
# 0             4.16        6.76          4.45         4.65  2015
# 1             4.35        7.73          4.78         4.46  2015
# 2             3.60        7.00          4.00         3.50  2015
# 3             3.90        9.03          4.60         6.30  2015
# 4             4.22        9.98          6.83         6.24  2015
# ..             ...         ...           ...          ...   ...
# 200           4.77       10.00          5.66         6.24  2025
# 201           4.61       12.80          6.87         9.55  2025
# 202           4.79       10.72          5.64         7.25  2025
# 203           4.41        8.87          6.70         6.70  2025
# 204           5.50        9.80          6.20        21.70  2025
#
# [205 rows x 5 columns]

# %%
# to find the mean reading time:
df["meanRT"] = df.mean(axis=1)
df
# Out:
#      Reading_NoInt  Naming_Int  Naming_NoInt  Reading_Int  Year   meanRT
# 0             4.16        6.76          4.45         4.65  2015  407.004
# 1             4.35        7.73          4.78         4.46  2015  407.264
# 2             3.60        7.00          4.00         3.50  2015  406.620
# 3             3.90        9.03          4.60         6.30  2015  407.766
# 4             4.22        9.98          6.83         6.24  2015  408.454
# ..             ...         ...           ...          ...   ...      ...
# 200           4.77       10.00          5.66         6.24  2025  410.334
# 201           4.61       12.80          6.87         9.55  2025  411.766
# 202           4.79       10.72          5.64         7.25  2025  410.680
# 203           4.41        8.87          6.70         6.70  2025  410.336
# 204           5.50        9.80          6.20        21.70  2025  413.640
#
# [205 rows x 6 columns]

# %%
# to get rid of the year
df = df.drop(["Year"],axis=1)
df
# it's giving me an error to say year doesnt exist as if i didnt know that! i got rid of it!
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[72], line 2
#       1 # to get rid of the year
# ----> 2 df = df.drop(["Year"],axis=1)
#       3 df
#       4 # it's giving me an error to say year doesnt exist as if i didnt know that! i got rid of it!
#
# File /opt/conda/lib/python3.13/site-packages/pandas/core/frame.py:6302, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    6298                 weight  250.0   150.0
#    6299         falcon  speed   320.0   250.0
#    6300                 weight  1.0     0.8
#    6301         """
# -> 6302         return super().drop(
#    6303             labels=labels,
#    6304             axis=axis,
#    6305             index=index,
#
# File /opt/conda/lib/python3.13/site-packages/pandas/core/generic.py:4632, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
# ...

# %%
df
# Out:
#      Reading_NoInt  Naming_Int  Naming_NoInt  Reading_Int   meanRT
# 0             4.16        6.76          4.45         4.65  407.004
# 1             4.35        7.73          4.78         4.46  407.264
# 2             3.60        7.00          4.00         3.50  406.620
# 3             3.90        9.03          4.60         6.30  407.766
# 4             4.22        9.98          6.83         6.24  408.454
# ..             ...         ...           ...          ...      ...
# 200           4.77       10.00          5.66         6.24  410.334
# 201           4.61       12.80          6.87         9.55  411.766
# 202           4.79       10.72          5.64         7.25  410.680
# 203           4.41        8.87          6.70         6.70  410.336
# 204           5.50        9.80          6.20        21.70  413.640
#
# [205 rows x 5 columns]
