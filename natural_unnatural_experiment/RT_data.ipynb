# %%
import pandas as pd

# %%
raw = pd.read_csv("/work/E26-experimental-psycholinguistics/natural_unnatural_experiment/combined_data.csv")

# %%
#raw.head(20)
# shows you the first x number of rows. default is 5 rows
#raw.head()

# %%
#raw.tail()
# .tail shows you the last rows of the data

# %%
list(raw)
#gives you a list of all the column names
# Out:
# ['participant_id',
#  'component_num',
#  'url',
#  'meta',
#  'sender',
#  'sender_type',
#  'sender_id',
#  'ended_on',
#  'duration',
#  'time_run',
#  'time_render',
#  'time_show',
#  'time_end',
#  'time_commit',
#  'timestamp',
#  'time_switch',
#  'response',
#  'response_action',
#  'prime',
#  'target',
#  'condition',
#  'soa_condition',
#  'congruence',
#  'correct_response',
#  'correctResponse',
#  'correct']

# %% [markdown]
# IVs - SOA, congruens
#
# DVs - response time, accuracy

# %%
cols = ['participant_id', "sender", "duration", "response", "condition", "soa_condition", "congruence", "correctResponse", "correct", "target", "prime"]

# %%
data = raw[cols]
data
# Out:
#        participant_id               sender   duration response condition  \
# 0                  51              Wecome1     499.56      NaN       NaN
# 1                  51              Wecome2     499.52      NaN       NaN
# 2                  51              Wecome3     499.52      NaN       NaN
# 3                  51        Instructions1    9061.10      NaN       NaN
# 4                  51      Instructions 1a    2279.00      NaN       NaN
# ...               ...                  ...        ...      ...       ...
# 15632              69           Short Loop   85426.00      NaN       NaN
# 15633              69                Break     868.30      NaN       NaN
# 15634              69       Short Sequence   86318.40      NaN       NaN
# 15635              69  Experiment Sequence  183618.50      NaN       NaN
# 15636              69                 root  216385.18      NaN       NaN
#
#       soa_condition congruence correctResponse correct target prime
# 0               NaN        NaN             NaN     NaN    NaN   NaN
# 1               NaN        NaN             NaN     NaN    NaN   NaN
# 2               NaN        NaN             NaN     NaN    NaN   NaN
# 3               NaN        NaN             NaN     NaN    NaN   NaN
# 4               NaN        NaN             NaN     NaN    NaN   NaN
# ...             ...        ...             ...     ...    ...   ...
# 15632           NaN        NaN             NaN     NaN    NaN   NaN
# 15633           NaN        NaN             NaN     NaN    NaN   NaN
# 15634           NaN        NaN             NaN     NaN    NaN   NaN
# 15635           NaN        NaN             NaN     NaN    NaN   NaN
# 15636           NaN        NaN             NaN     NaN    NaN   NaN
#
# [15637 rows x 11 columns]

# %%
data = data[data["sender"] == "target"]
# == means "is equal to", whereas = is assigning a value
# so this command only shows where the sender column has target as a value
data
# Out:
#        participant_id  sender  duration response        condition  \
# 13                 51  target    843.38        n         practice
# 19                 51  target    593.04        m         practice
# 25                 51  target    559.18        m         practice
# 31                 51  target    653.76        n         practice
# 40                 51  target    520.14        m  Inc_Synth_Synth
# ...               ...     ...       ...      ...              ...
# 15606              69  target    699.20        m        Con_Synth
# 15612              69  target    580.20        n          Con_Nat
# 15618              69  target    577.90        m    Inc_Nat_Synth
# 15624              69  target    661.10        n    Inc_Synth_Nat
# 15630              69  target    709.20        n      Inc_Nat_Nat
#
#       soa_condition   congruence correctResponse correct target    prime
# 13         practice     practice               n    True  SHEEP   snjghf
# 19         practice     practice               m    True   BOAT   iweonf
# 25         practice     practice               m    True  HOUSE   nvoiuh
# 31         practice     practice               n    True  HORSE  abjdhjs
# 40             long  incongruent               m    True  PIANO     roof
# ...             ...          ...             ...     ...    ...      ...
# 15606         short    congruent               m    True   BELT     belt
# 15612         short    congruent               n    True  DAISY    daisy
# 15618         short  incongruent               m    True   SHED    peach
# 15624         short  incongruent               n    True  HUSKY     rake
# 15630         short  incongruent               n    True  PETAL     fern
#
# [2356 rows x 11 columns]

# %%
sender_list = list(data["sender"])
sender_list
#this runs about a million lines of output. to condense it, we make it into a set
set(sender_list)
# Out:
# {'target'}

# %%
data["sender"].unique()
# Out:
# <StringArray>
# ['target']
# Length: 1, dtype: str

# %%
data = data[data["condition"] !="practice"]
data
#shows all the values of the condition column that are NOT practice
# Out:
#        participant_id  sender  duration response        condition  \
# 40                 51  target    520.14        m  Inc_Synth_Synth
# 47                 51  target    640.66        n      Inc_Nat_Nat
# 54                 51  target    597.74        n    Inc_Synth_Nat
# 61                 51  target    495.68        n          Con_Nat
# 68                 51  target    556.86        m    Inc_Nat_Synth
# ...               ...     ...       ...      ...              ...
# 15606              69  target    699.20        m        Con_Synth
# 15612              69  target    580.20        n          Con_Nat
# 15618              69  target    577.90        m    Inc_Nat_Synth
# 15624              69  target    661.10        n    Inc_Synth_Nat
# 15630              69  target    709.20        n      Inc_Nat_Nat
#
#       soa_condition   congruence correctResponse correct target  prime
# 40             long  incongruent               m    True  PIANO   roof
# 47             long  incongruent               m   False   BULL  sheep
# 54             long  incongruent               n    True   GOAT   fort
# 61             long    congruent               n    True   PEAR   pear
# 68             long  incongruent               m    True  MOTOR  olive
# ...             ...          ...             ...     ...    ...    ...
# 15606         short    congruent               m    True   BELT   belt
# 15612         short    congruent               n    True  DAISY  daisy
# 15618         short  incongruent               m    True   SHED  peach
# 15624         short  incongruent               n    True  HUSKY   rake
# 15630         short  incongruent               n    True  PETAL   fern
#
# [2280 rows x 11 columns]

# %%
data = data.drop(columns = ["sender"])
# removing sender because we know that it just says target every time. we know this from running the sender_list function
data
# Out:
#        participant_id  duration response        condition soa_condition  \
# 40                 51    520.14        m  Inc_Synth_Synth          long
# 47                 51    640.66        n      Inc_Nat_Nat          long
# 54                 51    597.74        n    Inc_Synth_Nat          long
# 61                 51    495.68        n          Con_Nat          long
# 68                 51    556.86        m    Inc_Nat_Synth          long
# ...               ...       ...      ...              ...           ...
# 15606              69    699.20        m        Con_Synth         short
# 15612              69    580.20        n          Con_Nat         short
# 15618              69    577.90        m    Inc_Nat_Synth         short
# 15624              69    661.10        n    Inc_Synth_Nat         short
# 15630              69    709.20        n      Inc_Nat_Nat         short
#
#         congruence correctResponse correct target  prime
# 40     incongruent               m    True  PIANO   roof
# 47     incongruent               m   False   BULL  sheep
# 54     incongruent               n    True   GOAT   fort
# 61       congruent               n    True   PEAR   pear
# 68     incongruent               m    True  MOTOR  olive
# ...            ...             ...     ...    ...    ...
# 15606    congruent               m    True   BELT   belt
# 15612    congruent               n    True  DAISY  daisy
# 15618  incongruent               m    True   SHED  peach
# 15624  incongruent               n    True  HUSKY   rake
# 15630  incongruent               n    True  PETAL   fern
#
# [2280 rows x 10 columns]

# %%
# i now cannot run the cell above without it showing an error because it then tries to remove a column that is already removed

# %%
data.loc[data["target"] == "BULL", "correct_response"] = "n"
data
# Out:
#        participant_id  duration response        condition soa_condition  \
# 40                 51    520.14        m  Inc_Synth_Synth          long
# 47                 51    640.66        n      Inc_Nat_Nat          long
# 54                 51    597.74        n    Inc_Synth_Nat          long
# 61                 51    495.68        n          Con_Nat          long
# 68                 51    556.86        m    Inc_Nat_Synth          long
# ...               ...       ...      ...              ...           ...
# 15606              69    699.20        m        Con_Synth         short
# 15612              69    580.20        n          Con_Nat         short
# 15618              69    577.90        m    Inc_Nat_Synth         short
# 15624              69    661.10        n    Inc_Synth_Nat         short
# 15630              69    709.20        n      Inc_Nat_Nat         short
#
#         congruence correctResponse correct target  prime correct_response
# 40     incongruent               m    True  PIANO   roof              NaN
# 47     incongruent               m   False   BULL  sheep                n
# 54     incongruent               n    True   GOAT   fort              NaN
# 61       congruent               n    True   PEAR   pear              NaN
# 68     incongruent               m    True  MOTOR  olive              NaN
# ...            ...             ...     ...    ...    ...              ...
# 15606    congruent               m    True   BELT   belt              NaN
# 15612    congruent               n    True  DAISY  daisy              NaN
# 15618  incongruent               m    True   SHED  peach              NaN
# 15624  incongruent               n    True  HUSKY   rake              NaN
# 15630  incongruent               n    True  PETAL   fern              NaN
#
# [2280 rows x 11 columns]

# %%
data["accuracy"] = data["response"] == data["correct_response"]
# making a new column to check whether the response is correct
data
# Out:
#        participant_id  duration response        condition soa_condition  \
# 40                 51    520.14        m  Inc_Synth_Synth          long
# 47                 51    640.66        n      Inc_Nat_Nat          long
# 54                 51    597.74        n    Inc_Synth_Nat          long
# 61                 51    495.68        n          Con_Nat          long
# 68                 51    556.86        m    Inc_Nat_Synth          long
# ...               ...       ...      ...              ...           ...
# 15606              69    699.20        m        Con_Synth         short
# 15612              69    580.20        n          Con_Nat         short
# 15618              69    577.90        m    Inc_Nat_Synth         short
# 15624              69    661.10        n    Inc_Synth_Nat         short
# 15630              69    709.20        n      Inc_Nat_Nat         short
#
#         congruence correctResponse correct target  prime correct_response  \
# 40     incongruent               m    True  PIANO   roof              NaN
# 47     incongruent               m   False   BULL  sheep                n
# 54     incongruent               n    True   GOAT   fort              NaN
# 61       congruent               n    True   PEAR   pear              NaN
# 68     incongruent               m    True  MOTOR  olive              NaN
# ...            ...             ...     ...    ...    ...              ...
# 15606    congruent               m    True   BELT   belt              NaN
# 15612    congruent               n    True  DAISY  daisy              NaN
# 15618  incongruent               m    True   SHED  peach              NaN
# 15624  incongruent               n    True  HUSKY   rake              NaN
# 15630  incongruent               n    True  PETAL   fern              NaN
#
#        accuracy
# 40        False
# 47         True
# 54        False
# 61        False
# 68        False
# ...         ...
# 15606     False
# 15612     False
# 15618     False
# 15624     False
# 15630     False
#
# [2280 rows x 12 columns]

# %%
data_grouped = data.groupby(["soa_condition", "congruence"]).mean(["duration"])
# everyone has got this error and we dont know why. ethan is going to fix it at some point
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 data_grouped = data.groupby(["soa_condition", "congruence"]).mean(["duration"])
#       2 # everyone has got this error and we dont know why. ethan is going to fix it at some point
#
# File /opt/conda/lib/python3.13/site-packages/pandas/core/groupby/groupby.py:2285, in GroupBy.mean(self, numeric_only, skipna, engine, engine_kwargs)
#    2277     return self._numba_agg_general(
#    2278         grouped_mean,
#    2279         executor.float_dtype_mapping,
#    (...)   2282         skipna=skipna,
#    2283     )
#    2284 else:
# -> 2285     result = self._cython_agg_general(
#    2286         "mean",
#    2287         alt=lambda x: Series(x, copy=False).mean(
#    2288             numeric_only=numeric_only, skipna=skipna
#    2289         ),
#    2290         numeric_only=numeric_only,
#    2291         skipna=skipna,
#    2292     )
#    2293     return result.__finalize__(self.obj, method="groupby")
#
# File /opt/conda/lib/python3.13/site-packages/pandas/core/groupby/groupby.py:1777, in GroupBy._cython_agg_general(self, how, alt, numeric_only, min_count, **kwargs)
#    1764 @final
#    1765 def _cython_agg_general(
#    1766     self,
#    (...)   1773     # Note: we never get here with how="ohlc" for DataFrameGroupBy;
#    1774     #  that goes through SeriesGroupBy
#    1776     if not is_bool(numeric_only):
# -> 1777         raise ValueError("numeric_only accepts only Boolean values")
#    1779     data = self._get_data_to_aggregate(numeric_only=numeric_only, name=how)
#    1781     def array_func(values: ArrayLike) -> ArrayLike:
#
# ValueError: numeric_only accepts only Boolean values

# %%
data_grouped = data

# %%
data_grouped = data_grouped.reset_index()
data_grouped
# Out:
#       index  participant_id  duration response        condition soa_condition  \
# 0        40              51    520.14        m  Inc_Synth_Synth          long
# 1        47              51    640.66        n      Inc_Nat_Nat          long
# 2        54              51    597.74        n    Inc_Synth_Nat          long
# 3        61              51    495.68        n          Con_Nat          long
# 4        68              51    556.86        m    Inc_Nat_Synth          long
# ...     ...             ...       ...      ...              ...           ...
# 2275  15606              69    699.20        m        Con_Synth         short
# 2276  15612              69    580.20        n          Con_Nat         short
# 2277  15618              69    577.90        m    Inc_Nat_Synth         short
# 2278  15624              69    661.10        n    Inc_Synth_Nat         short
# 2279  15630              69    709.20        n      Inc_Nat_Nat         short
#
#        congruence correctResponse correct target  prime correct_response  \
# 0     incongruent               m    True  PIANO   roof              NaN
# 1     incongruent               m   False   BULL  sheep                n
# 2     incongruent               n    True   GOAT   fort              NaN
# 3       congruent               n    True   PEAR   pear              NaN
# 4     incongruent               m    True  MOTOR  olive              NaN
# ...           ...             ...     ...    ...    ...              ...
# 2275    congruent               m    True   BELT   belt              NaN
# 2276    congruent               n    True  DAISY  daisy              NaN
# 2277  incongruent               m    True   SHED  peach              NaN
# 2278  incongruent               n    True  HUSKY   rake              NaN
# 2279  incongruent               n    True  PETAL   fern              NaN
#
#       accuracy
# 0        False
# 1         True
# 2        False
# 3        False
# 4        False
# ...        ...
# 2275     False
# 2276     False
# 2277     False
# 2278     False
# 2279     False
#
# [2280 rows x 13 columns]

# %%
# %pip install seaborn
# Out:
# Collecting seaborn
#   Downloading seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /opt/conda/lib/python3.13/site-packages (from seaborn) (2.5.2)
# Requirement already satisfied: pandas>=1.2 in /opt/conda/lib/python3.13/site-packages (from seaborn) (3.0.5)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /opt/conda/lib/python3.13/site-packages (from seaborn) (3.11.1)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.13/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.13/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.28.2 in /opt/conda/lib/python3.13/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/conda/lib/python3.13/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.13/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (26.2)
# Requirement already satisfied: pillow>=9 in /opt/conda/lib/python3.13/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (12.3.0)
# Requirement already satisfied: pyparsing>=3 in /opt/conda/lib/python3.13/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.13/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.13/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
# Installing collected packages: seaborn
# Successfully installed seaborn-0.13.2
# Note: you may need to restart the kernel to use updated packages.

# %%
import seaborn as sns
# a new library that makes matplotlib library simpler

# %%
ax = sns.barplot(data = data_grouped, x = "congruence", y = "duration", hue = "soa_condition")
sns.move_legend(ax, "center")

# %%
df_grouped = data.groupby(["participant_id", "soa_condition", "congruence"])(["rt"]).mean().reset_index()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 df_grouped = data.groupby(["participant_id", "soa_condition", "congruence"])(["rt"]).mean().reset_index()
#
# TypeError: 'DataFrameGroupBy' object is not callable
