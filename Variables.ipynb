# %% [markdown]
# # Variables and variable types
#
# ## "Regular" variables
#
# 1. strings
# 1. integers
# 1. floats
#
# ## "Collection" variables
#
# 1. tuples
# 1. lists
# 1. sets
# 1. dictionaries
#
# From https://www.w3schools.com:
#
# - **Strings** are for storing text
# - **Integers** are for storing whole numbers, positive or negative (such as 123 or -456), without decimals.
# - **Floats** are for storing positive and negative numbers with a decimal point, like 35.3, or -2.34
# - **Lists** are collections which are ordered and changeable. Allows duplicate members.
# - **Tuples** are collections which are ordered and unchangeable. Allows duplicate members.
# - **Sets** are collections which are unordered, "unchangeable", and unindexed. No duplicate members.
# - **Dictionaries** are collections which are ordered and changeable. No duplicate members.

# %% [markdown]
# lists [] items sep with commas
#
# sets {} items sep with commas
#
# tuples() items sep with commas
#
# dictionary {} items sep with commas, defined with colons

# %% [markdown]
# ## Strings

# %%
name = "John"

# %% [markdown]
# ## Integers

# %%
number = 18

# %% [markdown]
# ## Floats

# %%
another_number = 6.25

# %% [markdown]
# ## Lists

# %%
aList = [9, 400, 78]
aList[1]
aList[0] = 5
aList
# Out:
# [5, 400, 78]

# %% [markdown]
# the first position number is "400" because python starts counting at number 0. therefore the first item in a list is 0, the second item is 1, third item is 2 and so on
#
# a list is variable - you can change the items in the list from outside the list

# %%
anotherList = [name, number, another_number]
anotherList
# Out:
# ['John', 18, 6.25]

# %% [markdown]
# lists can be mixed variable types

# %%
anotherList[2]
# Out:
# 6.25

# %%
anotherList[2] = "python"
anotherList
# Out:
# ['John', 18, 'python']

# %% [markdown]
# ## Tuples

# %%
shopping_list = ["apples", "pears", "bananas"]
shopping_tuple = ("apples", "pears", "bananas")

# %%
shopping_list[1]
# Out:
# 'pears'

# %%
shopping_tuple[1]
# Out:
# 'pears'

# %%
shopping_list[1] = "grapes"
shopping_list
# Out:
# ['apples', 'grapes', 'bananas']

# %%
shopping_tuple[1] = "grapes"
shopping_tuple
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 shopping_tuple[1] = "grapes"
#       2 shopping_tuple
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# items in tuples are not changeable.
#
# why would you use a tuple, one might ask? maybe if you need to be sure that the data does not under any circumstances change. probably some better reasons also but safe data storage is a big one

# %% [markdown]
# ## Sets

# %%
newList = [4, 4, 7, 19, 21, "i am a string", 7.23]
mySet = set(newList)
mySet
# Out:
# {19, 21, 4, 7, 7.23, 'i am a string'}

# %% [markdown]
# no duplicate members in sets. also unordered and unchangeable. somewhat random order but this is not that important
#
# sets are useful for looking for types vs tokens - e.g. a text with lots of duplicate words where you don't care about how many times a word appears but are looking at how many different words there are

# %%
mySet[3]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 mySet[3]
#
# TypeError: 'set' object is not subscriptable

# %% [markdown]
# no fixed order in a set, therefore you can't isolate an item

# %%
anotherSet = {9, 12, 15}
anotherSet
# Out:
# {9, 12, 15}

# %%
type(anotherSet)
# Out:
# set

# %%
oneMoreSet = set(29, 40, 6)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 oneMoreSet = set(29, 40, 6)
#
# TypeError: set expected at most 1 argument, got 3

# %% [markdown]
# you can't make a set using the set function with more than one argument for some reason. you can make a set out of a list (i.e. the data for the set is gathered first in a list) or you can make a set directly from the data using curly brackets.

# %% [markdown]
# ## Dictionaries

# %%
my_pet = {"name": "James",
          "species": "cat", 
          "likes": "sleeping", 
          "dislikes": "mice", 
          "age": 10}
#you dont have to separate the entries with new lines but it just makes it look nicer right now

# %%
my_pet["age"]
# Out:
# 10

# %%
items = ["musli", "juice", "bread", ["salt", "pepper", "cumin"]]
#there is a list inside the list as the last item
number = [1, 4, 3, 8]
#number of items
priority = ["high", "high", "very high", "low"]

# %%
shopping = {"items": items, "number": number, "priority": priority}
#shopping is now the dictionary

# %%
shopping["items"]
# Out:
# ['musli', 'juice', 'bread', ['salt', 'pepper', 'cumin']]

# %%
shopping["items"][2]
# Out:
# 'bread'

# %%
shopping["items"][3]
# Out:
# ['salt', 'pepper', 'cumin']

# %%
shopping["items"][3][1]
#singling out a specific item from the list within the list
# Out:
# 'pepper'

# %%
greens = ["forest", "lime", "pastel"]
colours = ["red", "orange", greens]
#here greens is not in speech marks because it's a list, not a singular item
amount = ["a litre", "two cans", "four litres"]

# %%
paint = {"colours": colours, 
                "amount": amount}

# %%
paint["colours"]
# Out:
# ['red', 'orange', ['forest', 'lime', 'pastel']]

# %%
other_things = ["toilet paper", "face wash", "paint brush"]

# %%
shopping_list = {"paint": paint, 
                 "shopping": shopping, 
                 "other things": other_things}

shopping_list
# Out:
# {'paint': {'colours': ['red', 'orange', ['forest', 'lime', 'pastel']],
#   'amount': ['a litre', 'two cans', 'four litres']},
#  'shopping': {'items': ['musli',
#    'juice',
#    'bread',
#    ['salt', 'pepper', 'cumin']],
#   'number': [1, 4, 3, 8],
#   'priority': ['high', 'high', 'very high', 'low']},
#  'other things': ['toilet paper', 'face wash', 'paint brush']}

# %%
shopping_list["other things"][2]
# Out:
# 'paint brush'
