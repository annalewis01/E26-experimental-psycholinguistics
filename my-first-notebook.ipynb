# %% [markdown]
# ## my first notebook <3
#
# basic types of variables in Python:
#
# 1. strings
# 2. integers
# 3. floats
#
# (*what is a variable?*
# - a thing that you store other things in)
#
# **vamos**

# %% [markdown]
# ## useful bits
#
# click to select cell
#
# - m = markdown
# - y = code
# - dd = delete
# - a = new cell above
# - b = new cell below
# - shift + enter = send
# - enter or double click = edit a sent cell
#
# python is CASE SPECIFIC when assigning values
#
# a hash # will make python ignore everything else on that line

# %% [markdown]
# ## integers
#
# an integer is a whole number

# %%
7 + 3
# Out:
# 10

# %%
chips = 2
cookies = 3
chips + cookies
# Out:
# 5

# %% [markdown]
# this is how we assign/define variables. you can call your variables almost anything you want
# - you can't call a variable an integer. e.g. 1 = 2 will **not** work
#
# this method is called dynamic typing

# %%
snacks = chips + cookies

# %%
type(snacks)
# Out:
# int

# %% [markdown]
# a **function** (like *type*) has **parentheses**
#
# you can use type() to find out what type of variable you have

# %%
print(snacks)
# Out:
# 5

# %%
snacks
# Out:
# 5

# %% [markdown]
# this jupyter-specific trick of just writing the variable only works on the last value.

# %%
chips
cookies
snacks
# Out:
# 5

# %%
print(chips, cookies, snacks)
print(chips)
print(cookies)
print(snacks)
# Out:
# 2 3 5
# 2
# 3
# 5

# %% [markdown]
# ## floats
#
# a float is a number with a decimal point

# %%
cookies = 3.2
apples = 4.7

# %%
type(cookies)
# Out:
# float

# %% [markdown]
# now cookies has been assigned two values. this overrides the first one (so the variable latest run will override)
#
# python will NOT tell you when it overrides a value. be aware - you can in this way mess up with variables
#
# if you suspect that the states of the variables have been changed at some point, go back and run all the code again to make sure

# %% [markdown]
# ## strings
#
# a string is representation of a character. not assigned a numerical value
#
# you can use either single ' or double " speech marks for strings in python

# %%
fruit = "grapes"
print(fruit)
# Out:
# grapes

# %%
fruit = "2"
print(fruit)
# Out:
# 2

# %%
fruit + chips
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 fruit + chips
#
# TypeError: can only concatenate str (not "int") to str

# %%
fruits = int(fruit)
print(fruit)
# Out:
# 2

# %%
# comments are good for leaving little messages to yourself, but also good for blocking out bits of code that you either need to debug or need to change
# you can also comment out part of a code that works if you want to change something with it without completely deleting it

# %%
fruit1 ="grapes"
fruit2 = "bananas"
fruit1 + fruit2
# Out:
# 'grapesbananas'

# %% [markdown]
# you can add strings to other strings, but you cannot add strings to numbers (integers or floats)

# %% [markdown]
# ## properties

# %%
type(snacks)
# Out:
# int

# %%
dir(snacks)
# Out:
# ['__abs__',
#  '__add__',
#  '__and__',
#  '__bool__',
#  '__ceil__',
#  '__class__',
#  '__delattr__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__float__',
#  '__floor__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getnewargs__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__index__',
#  '__init__',
#  '__init_subclass__',
#  '__int__',
#  '__invert__',
#  '__le__',
#  '__lshift__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
#  '__new__',
#  '__or__',
#  '__pos__',
#  '__pow__',
#  '__radd__',
#  '__rand__',
#  '__rdivmod__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rfloordiv__',
#  '__rlshift__',
#  '__rmod__',
#  '__rmul__',
#  '__ror__',
#  '__round__',
#  '__rpow__',
#  '__rrshift__',
#  '__rshift__',
#  '__rsub__',
#  '__rtruediv__',
#  '__rxor__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__sub__',
#  '__subclasshook__',
#  '__truediv__',
#  '__trunc__',
# ...

# %%
type(apples)
# Out:
# float

# %%
dir(apples)
# Out:
# ['__abs__',
#  '__add__',
#  '__bool__',
#  '__ceil__',
#  '__class__',
#  '__delattr__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__float__',
#  '__floor__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getformat__',
#  '__getnewargs__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__int__',
#  '__le__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
#  '__new__',
#  '__pos__',
#  '__pow__',
#  '__radd__',
#  '__rdivmod__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rfloordiv__',
#  '__rmod__',
#  '__rmul__',
#  '__round__',
#  '__rpow__',
#  '__rsub__',
#  '__rtruediv__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__sub__',
#  '__subclasshook__',
#  '__truediv__',
#  '__trunc__',
#  'as_integer_ratio',
#  'conjugate',
#  'fromhex',
#  'hex',
#  'imag',
#  'is_integer',
#  'real']

# %%
type(fruit)
# Out:
# str

# %%
dir(fruit)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'removeprefix',
# ...

# %% [markdown]
# you can mess around with these properties to change the assigned value of the variable
#
# especially with strings, these text manipulations are a good idea to have up your sleeve

# %%
fruit1.upper()
# Out:
# 'GRAPES'

# %%
fruit1.lower()
# Out:
# 'grapes'

# %% [markdown]
# it's a good idea to put text values in lowercase straight away to avoid any case problems later on

# %%
fruit1.replace("a","f")
# Out:
# 'grfpes'
