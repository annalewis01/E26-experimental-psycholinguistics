# %%
#def function_name(input1, input2):

# %%
name = "Anna"
birth = "2002"

# %%
def make_username(first, year):
    username = first.lower().replace(" ","") + year
    print(username)
    #first and year are just random inputs. they're not defined so they dont need to be anything specific. 
    #first could also be input1, e.g.

# %%
make_username(name, birth)
# Out:
# anna2002

# %%
#solution for username exercise from last week (last ex. from no. 2 - fun with variables)

# %% [markdown]
# now something different:
#
# ## here you can see what value is assigned to which variable name!!!! super cool and can tell you if something is or is not run through yet

# %%
pip install variable_inspector
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## WHILE LOOPS

# %%
time = 1
while time < 10:
    print(time)
    time = time +2
# Out:
# 1
# 3
# 5
# 7
# 9

# %% [markdown]
# ## FOR LOOPS

# %%
names = ["name1", "name2", "name3", "name4"]

for name in names: 
    print(name)
# Out:
# name1
# name2
# name3
# name4

# %% [markdown]
# ## IF STATEMENTS
